# %% [markdown]
# # ▶️ Capítulo 8 — Lendo dados externos
#
# ## 💾 Manipulação de Dados
#
# * **Ler um CSV com pandas:** Utilizando a biblioteca fundamental para I/O de dados.
# * **Mostrar tabela com dash-ag-grid ou dash_table:** Exibindo os dados brutos no app.
# * **Explicar brevemente limites e vantagens:** Considerações sobre performance e visualização de tabelas grandes.
#
# ---

# %% [markdown]
# # PROCESSAMENTO de dados com Pandas
#
# O Pandas é a ferramenta essencial para manipulação de dados em Python. Ele permite que você transforme dicionários ou arquivos brutos em estruturas tabulares chamadas DataFrames.
#
# Principais Operações Realizadas:
# Criação do DataFrame: Convertendo um dicionário Python em uma tabela estruturada.
#
# Exportação para Excel: O método .to_excel() gera um arquivo .xlsx, ideal para usuários que dependem de planilhas.
#
# Exportação para CSV: O método .to_csv() salva os dados em formato de texto delimitado, que é leve e universal para sistemas de dados.

# %%
import pandas as pd

# Criando o DataFrame conforme o exemplo da imagem
dados = {
    "Cidade": ["João Pessoa", "João Pessoa", "João Pessoa", "Campina Grande", "Campina Grande", "Campina Grande", "Patos", "Patos", "Patos"],
    "Ano": [2000, 2010, 2022, 2000, 2010, 2022, 2000, 2010, 2022],
    "Populacao": [597934, 723515, 833932, 355331, 385213, 419379, 91402, 100674, 103165],
    "PIB_Bilhoes": [5.2, 14.8, 22.1, 3.1, 7.8, 10.3, 0.5, 1.2, 2.1]
}

df = pd.DataFrame(dados)

# Exportando para Excel e CSV (como mostrado no seu código)
df.to_excel("cidades_pb_excel.xlsx", index=False)
df.to_csv("cidades_pb.csv", index=False)

# Para ler o arquivo posteriormente:
# df_lido = pd.read_csv("cidades_pb.csv")
df.head()
# Out:
#            Cidade   Ano  Populacao  PIB_Bilhoes
# 0     João Pessoa  2000     597934          5.2
# 1     João Pessoa  2010     723515         14.8
# 2     João Pessoa  2022     833932         22.1
# 3  Campina Grande  2000     355331          3.1
# 4  Campina Grande  2010     385213          7.8

# %% [markdown]
# # Visualização tabular com o componente dash_ag_grid
#
# O Dash AG Grid é uma das bibliotecas mais poderosas para exibir tabelas interativas, permitindo que o usuário filtre e ordene dados diretamente no navegador.
#
# Configurações Utilizadas (dashGridOptions):
# pagination: Ativa a quebra da tabela em páginas, evitando que a tela fique excessivamente longa.
#
# paginationPageSize: Define exatamente quantas linhas serão exibidas por vez (no seu caso, 20).
#
# defaultColDef: Define comportamentos padrão para todas as colunas, como permitir redimensionamento e filtros.

# %%
import pandas as pd
from dash import Dash, html
import dash_ag_grid as dag


# Opção A: URL Externa (Gapminder)
url_gapminder = "https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv"
df = pd.read_csv(url_gapminder)

# Opção B: Arquivo Local (Exemplo de cidades da PB que salvamos)
# df = pd.read_csv("cidades_pb.csv")

# Opção C: Dados de Pesquisa UFPB (Exemplo conceitual)
# df = pd.read_csv("projetos_pesquisa_ufpb.csv") 


app = Dash(__name__)

app.layout = html.Div([
    html.H3("Visualizador de Dados Dinâmico"),
    dag.AgGrid(
        id="tabela-dados",
        # Transformamos o DF escolhido acima em registros para o AG Grid
        rowData=df.to_dict("records"), 
        columnDefs=[{"field": i} for i in df.columns],
        defaultColDef={"resizable": True, "sortable": True, "filter": True},
        dashGridOptions={
            "pagination": True, 
            "paginationPageSize": 20
        }
    )
])

if __name__ == "__main__":
    # Usando app.run para evitar erros de versão obsoleta
    app.run(debug=True)
