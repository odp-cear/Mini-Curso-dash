# %% [markdown]
# # ▶️ Capítulo 3 — Primeiro app: "Hello Dash"
#
# ## 🚀 Primeiro Contato
#
# * **Criar app.py:** O arquivo principal da nossa aplicação.
# * **Explicar:** O objeto `Dash()`, a propriedade `layout` e o componente `html.Div`.
# * **Rodar no navegador:** Verificando a aplicação em funcionamento.
# * **Mostrar hot-reload:** Entendendo a atualização automática do servidor.
#
# ---

# %%
# Aula - Capítulo 3
# 1 - Criar arquivo "app.py"
# 2 - Explicar: Dash(); layou; html.div
# 3 - Rodar o app no navegador (porta de saída do terminal)
# 4 - Explicar hot-reload (atualização ao vivo)

# %% [markdown]
# Ponto 1 : Criar um arquivo
#
# Para escrever o nosso primeiro código
# usando o Dash, precisamos criar um arquivo Python.
#
# Passo a Passo:
# - 1 -> Abrir o VScode
# - 2 -> Abrir a pasta do projeto no VScode;
# - 3 -> Criar um arquivo Python ou Ipynb dentro da pasta;
# - 4 -> Nomear o arquivo como "app.py"

# %% [markdown]
# Ponto 2 : Dash(), Layout e html.div o que são?
#
# Dash() -> 1 estrutura necessária para escrever um código usando o Dash.
# > Classe principal da aplicação
#  -> Representa o servidor web e o objeto central que controla o app todo
#
# O dash() instancia uma aplicação web baseada em Flask e React.js
# > Abstraindo a comunicação entre Python e JavaScript
#
# > Serve para criar o nosso aplicativo dash:
# - Gerenciar layout;
# - Gerenciar callbacks
#
# OBS: Sem o dash(), o app NÃO existe!!!
#
# No código usamos da seguinte forma:
# > app = Dash()
#
# Layout -> Define a estrutura visual da aplicação dash.
#
# - Descreve a organização da interface gráfica do usuário
#
# > O dash lê o layout e constrói o HTML da página automaticamente
#
# -> Com o layout o programador está dizendo como a página será
# desenhada. Tudo o que aparece na tela vem do layout.
#
# No código usamos:
# app.layout = [html.Div]....
#
# html.div -> É a representação em Python da tag HTML<div>
#
# > Componente de Layout usado para agrupar, organizar e estruturar
# outros componentes da interface
#
# -> Organiza os elementos.
#
# No código usamos:
# [html.Div(children='....')]

# %%
## Código Hello dash > escrito no arquivo app.py:

#Primeiro passo : Importar a biblioteca necessária
from dash import Dash, html, dcc

#Segundo passo:
#Criar o app Dash com:
app = Dash()

#Terceiro passo: 
#Construir o layout da aplicação com:
app.layout = [html.Div(children='Olá Dash, primeira aplicação!')]

#Último passo:
#Rodar o app com:
if __name__ == '__main__':
    app.run(debug=True, port=8051) #apenas mudei a porta para 8051.
    #app.run(degub=True) >>> Rodar normal, sem mudança de porta
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Passo 3 : Rodar o app no navegador
#
# Passo a passo:
# - 1 -> Terminal;
# - 2 -> Novo terminal;
# - 3 -> Digitar o comando "Python app.py";
# - 4 -> Copiar a porta http de saída do terminal;
# - 5 -> Abrir o navegador;
# - 6 -> Colar a porta http no navegador;
# - 7 -> Saída esperada : "Olá Dash, primeira aplicação!"

# %%
## Código utilizado no passo 4 >>> Mudança para verificar hot-reload
## Código Hello dash > escrito no arquivo app.py:

#Primeiro passo : Importar a biblioteca necessária
from dash import Dash, html, dcc

#Segundo passo:
#Criar o app Dash com:
app = Dash()

#Terceiro passo: 
#Construir o layout da aplicação com:
app.layout = [html.Div(children='Olá Dash, programando!')] ##Mudança realizada.

#Último passo:
#Rodar o app com:
if __name__ == '__main__':
    app.run(debug=True, port=8051) #apenas mudei a porta para 8051.
    #app.run(degub=True) >>> Rodar normal, sem mudança de porta
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Passo 4 : Entendendo o hot-reload
#
# O que é hot-reload?
# - Atualização automática do dashboard de acordo com
# a edição do seu código. Atualização direto na web.
#
# - => Mudança sem que seja preciso rodar o app novamente;
# - => Sem necessidade de uma ação do usuário;
# - => Atualização automática;
# - => Comunicação em tempo real com seu código e dados.
