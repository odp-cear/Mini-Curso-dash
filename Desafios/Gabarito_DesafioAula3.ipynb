# %% [markdown]
# GABARITO DO DESAFIO 3:
#
# - 1: Construir código Hello Dash
# - 2: Rodar o app via terminal
# - 3: Subtítulo "Meu primeiro código utilizando Dash"
# - 4: Modificar o título para "Minicurso Python Dash"

# %% [markdown]
# 1 Parte:
#
# - Construção do código "Hello Dash!"

# %%
# 1°  passo: Código Hello Dash.
## Código Hello dash > escrito no arquivo app.py:

#Primeiro passo : Importar a biblioteca necessária
from dash import Dash, html, dcc

#Segundo passo:
#Criar o app Dash com:
app = Dash()

#Terceiro passo: 
#Construir o layout da aplicação com:
app.layout = [html.Div(children='Hello Dash!')]

#Último passo:
#Rodar o app com:
if __name__ == '__main__':
    app.run(debug=True=True)
    #app.run(degub=True) >>> Rodar normal, sem mudança de porta

# %% [markdown]
# Passo 2:
# - Executar o app via terminal
# - 1 -> Terminal
# - 2 -> Novo terminal
# - 3 -> Entrar no diretório
# - 4 -> Escrever no terminal "python app.py"

# %% [markdown]
# Passo 3:
# - Adicionar subtítulo "Meu primeiro código utilizando Dash!"

# %%
# 1°  passo: Código Hello Dash.
## Código Hello dash > escrito no arquivo app.py:

# Primeiro passo: Importar a biblioteca necessária
from dash import Dash, html, dcc

# Segundo passo:
# Criar o app Dash com:
app = Dash()

# Terceiro passo: 
# Construir o layout da aplicação com:
app.layout = html.Div(children=[
    html.H1(children='Hello Dash!'),
    html.H2(children='Meu primeiro código utilizando Dash!'),
])

# Último passo:
# Rodar o app com:
if __name__ == '__main__':
    app.run(debug=True)
    # app.run(debug=True) >>> Rodar normal, sem mudança de porta

# %% [markdown]
# Passo 4:
# - Mudar o título do dashboard para "Minicurso Python Dash"

# %%
# 1°  passo: Código Hello Dash.
## Código Hello dash > escrito no arquivo app.py:

# Primeiro passo: Importar a biblioteca necessária
from dash import Dash, html, dcc

# Segundo passo:
# Criar o app Dash com:
app = Dash()

# Terceiro passo: 
# Construir o layout da aplicação com:
app.layout = html.Div(children=[
    html.H1(children='Minicurso Python Dash'),
    html.H2(children='Meu primeiro código utilizando Dash!'),
])

# Último passo:
# Rodar o app com:
if __name__ == '__main__':
    app.run(debug=True)
    # app.run(debug=True) >>> Rodar normal, sem mudança de porta
