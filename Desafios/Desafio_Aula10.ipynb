# %% [markdown]
# # Com Base no que foi introduzido na aula 10, implemente o desafio a seguir:
#
# 1. Prepare a sua aplicação para se tornar um servidor.
#
# 2. Estruture o seu repositorio. (requirements.txt, pasta de dados...)
#
# 3. Publique Localmente.
