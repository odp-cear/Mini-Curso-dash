# %% [markdown]
# # Com Base no que foi introduzido na aula 09, implemente o desafio a seguir:
#
# 1. Do Codigo anterior, Estilize os componentes que foram usados com o css externo ou interno.
#
# 2. Refaça o codigo anterior agora utilizando a biblioteca dash-bootstrap-components. Implemente a estrutura da biblioteca. html div -> Dbc container
