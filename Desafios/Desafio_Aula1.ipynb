# %% [markdown]
# NESSE ARQUIVO VOCÊ IRÁ CONSTRUIR O SEU CÓDIGO DO DESAFIO 1:
#
# Desafio 1:
# Construir uma rotina python usando Jupyter Notebook que mostra na tela:
# - 1 > Texto contendo : "Meu nome é: "
# - 2 > Código que mostre seu nome
# - 3 > Texto contendo : "Minha idade é: "
# - 4 > Código que mostre sua idade
