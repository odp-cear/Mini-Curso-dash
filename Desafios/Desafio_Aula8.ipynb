# %% [markdown]
# # Com Base no que foi introduzido na aula 08, implemente o desafio a seguir:
#
# 1. Faça um dataframe da biblioteca pandas para usar de base de dados.
#
# 2. Monte uma tabela interativa com o componente dash Ag-Grid.
